# %% [markdown]
# # 2. Breast Cancer Detection Using INbreast Dataset

# %% [markdown]
# #### 2.1 Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import pydot
import matplotlib.pyplot as plt
import cv2
import os
from numpy.random import seed
seed(101)

import tensorflow
from keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model

import h5py
from keras.utils import np_utils
from keras import backend as K
from keras.models import load_model 
from keras.utils.vis_utils import plot_model
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import timeit
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### 1.2 Loading the dataset

# %%
## loading the INbreast data
folder_path_INbreast = 'E:/NN project/Dataset of Mammography with Benign Malignant Breast Masses/INbreast Dataset/'
num_of_epochs = 100
batchsize = 128
image_class_label = 0
INbreast_data_labels = []
INbreast_data_images = []

# %%
def loading_images_from_folder(folder, image_class_label):
	for file_name in os.listdir(folder):
		og_img = cv2.imread(os.path.join(folder, file_name))
		if og_img is not None:
			og_img = cv2.resize(og_img, (140,92))  ## resizing the image
			og_img = og_img.reshape(92,140,3)
			INbreast_data_images.append(og_img)				 ## Appending all the resized Images
			INbreast_data_labels.append(image_class_label)		 ## Adding the respective labels
		
	image_class_label += 1
	return image_class_label

# %%
image_class_label = loading_images_from_folder(folder_path_INbreast+'Malignant Masses', image_class_label)
image_class_label = loading_images_from_folder(folder_path_INbreast+'Benign Masses', image_class_label)

# %%
# converting the images to an array
INbreast_Data = np.asarray(INbreast_data_images)
INbreast_Labels = np.asarray(INbreast_data_labels)
print("Shape of InBreast Data - ", INbreast_Data.shape)
# Out:
# Shape of InBreast Data -  (7632, 92, 140, 3)

# %% [markdown]
# #### 1.3 Splitting INbreast dataset

# %%
# Splitting the "INbreast" Data as Train, Validation and Test
X_train, X_test, y_train, y_test = train_test_split(INbreast_Data, INbreast_Labels, test_size=0.2, random_state=21)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1)

# %%
## Size of dataset before Normalization
print("Before Normalization - ")
print("Shape of X Train = ", X_train.shape, "Shape of X test = ", X_test.shape)
print("Shape of Y Train = ", y_train.shape, "Shape of Y Test = ", y_test.shape)
print("Shape of X Validation = ", X_valid.shape, "Shape of Y Validation = ", y_valid.shape)
# Out:
# Before Normalization -
# Shape of X Train =  (5494, 92, 140, 3) Shape of X test =  (1527, 92, 140, 3)
# Shape of Y Train =  (5494,) Shape of Y Test =  (1527,)
# Shape of X Validation =  (611, 92, 140, 3) Shape of Y Validation =  (611,)

# %%
# Normalizing the data
X_train = X_train / 255  ## original scale : 255
X_valid = X_valid / 255         ## new image scale : 0-1
X_test = X_test / 255
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_valid = np_utils.to_categorical(y_valid)
y_test = np_utils.to_categorical(y_test)
number_of_classes = y_test.shape[1]

# %%
# Printing the results After Normalization
print("After Normalization -")
print("Shape of X Train = ", X_train.shape, "Shape of X test = ", X_test.shape)
print("Shape of Y Train = ", y_train.shape, "Shape of Y Test = ", y_test.shape)
print("Shape of X Validation = ", X_valid.shape, "Shape of Y Validation = ", y_valid.shape)
# Out:
# After Normalization -
# Shape of X Train =  (5494, 92, 140, 3) Shape of X test =  (1527, 92, 140, 3)
# Shape of Y Train =  (5494, 2) Shape of Y Test =  (1527, 2)
# Shape of X Validation =  (611, 92, 140, 3) Shape of Y Validation =  (611, 2)

# %%
# Showing the Images
plt.figure(figsize=(11,3))
for i in range(10):
  plt.subplot(2,5,1+i)
  plt.imshow(X_train[i], cmap='gray')

# %% [markdown]
# #### 1.4.1 Advance Building Model for INbreast Data

# %%
# Advanced CNN model for INbreast Dataset - Adding more layers to the model
def adv_breastCancer_model():
	adv_model = Sequential()
	adv_model.add(Conv2D(32, (3, 3), input_shape=(92,140,3), activation='relu', padding="same"))
	adv_model.add(MaxPooling2D(pool_size=(2, 2)))
	adv_model.add(Conv2D(32, (3, 3), activation='relu', padding = 'same'))  
	adv_model.add(MaxPooling2D(pool_size=(2, 2)))
	adv_model.add(Conv2D(64, (3, 3), activation='relu', padding = 'same'))  ## new layer added
	adv_model.add(MaxPooling2D(pool_size=(2, 2)))
	adv_model.add(Conv2D(128, (3, 3), activation='relu', padding = 'same'))  ## new layer added
	adv_model.add(MaxPooling2D(pool_size=(2, 2)))
	adv_model.add(Dropout(0.5))
	adv_model.add(Flatten())
	adv_model.add(Dropout(0.5))
	adv_model.add(Dense(50, activation='relu'))		 ## new layer added
	adv_model.add(Dropout(0.2))
	adv_model.add(Dense(number_of_classes, activation='softmax'))

	adv_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
	return adv_model

# %%
# Building the model
adv_model = adv_breastCancer_model()
adv_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 92, 140, 32)       896
#
#  max_pooling2d_4 (MaxPooling  (None, 46, 70, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 46, 70, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 23, 35, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 23, 35, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 11, 17, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 17, 128)       73856
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 8, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 5, 8, 128)         0
#
#  flatten_1 (Flatten)         (None, 5120)              0
#
#  dropout_4 (Dropout)         (None, 5120)              0
#
#  dense_2 (Dense)             (None, 50)                256050
#
#  dropout_5 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 358,648
# Trainable params: 358,648
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the CNN model
start = timeit.default_timer()
adv_hist = adv_model.fit(X_train, y_train, validation_data=(X_valid, y_valid), 
                            batch_size=batchsize, epochs=num_of_epochs)
stop = timeit.default_timer()
print("Time: ", round((stop - start),2), "seconds")
# Out:
# Epoch 1/100
# 43/43 [==============================] - 27s 616ms/step - loss: 0.6451 - accuracy: 0.6656 - val_loss: 0.6320 - val_accuracy: 0.6694
# Epoch 2/100
# 43/43 [==============================] - 26s 605ms/step - loss: 0.6363 - accuracy: 0.6660 - val_loss: 0.6372 - val_accuracy: 0.6694
# Epoch 3/100
# 43/43 [==============================] - 26s 606ms/step - loss: 0.6354 - accuracy: 0.6660 - val_loss: 0.6335 - val_accuracy: 0.6694
# Epoch 4/100
# 43/43 [==============================] - 27s 630ms/step - loss: 0.6327 - accuracy: 0.6660 - val_loss: 0.6302 - val_accuracy: 0.6694
# Epoch 5/100
# 43/43 [==============================] - 27s 619ms/step - loss: 0.6300 - accuracy: 0.6660 - val_loss: 0.6287 - val_accuracy: 0.6694
# Epoch 6/100
# 43/43 [==============================] - 27s 625ms/step - loss: 0.6285 - accuracy: 0.6660 - val_loss: 0.6314 - val_accuracy: 0.6694
# Epoch 7/100
# 43/43 [==============================] - 26s 603ms/step - loss: 0.6267 - accuracy: 0.6658 - val_loss: 0.6236 - val_accuracy: 0.6694
# Epoch 8/100
# 43/43 [==============================] - 27s 620ms/step - loss: 0.6176 - accuracy: 0.6704 - val_loss: 0.6198 - val_accuracy: 0.6759
# Epoch 9/100
# 43/43 [==============================] - 27s 639ms/step - loss: 0.6173 - accuracy: 0.6689 - val_loss: 0.6159 - val_accuracy: 0.6612
# Epoch 10/100
# 43/43 [==============================] - 27s 619ms/step - loss: 0.6089 - accuracy: 0.6740 - val_loss: 0.6061 - val_accuracy: 0.6612
# Epoch 11/100
# 43/43 [==============================] - 27s 617ms/step - loss: 0.6016 - accuracy: 0.6762 - val_loss: 0.5979 - val_accuracy: 0.6727
# Epoch 12/100
# 43/43 [==============================] - 26s 617ms/step - loss: 0.5869 - accuracy: 0.6851 - val_loss: 0.5908 - val_accuracy: 0.6907
# Epoch 13/100
# 43/43 [==============================] - 27s 627ms/step - loss: 0.5773 - accuracy: 0.6959 - val_loss: 0.5812 - val_accuracy: 0.6890
# Epoch 14/100
# 43/43 [==============================] - 27s 625ms/step - loss: 0.5624 - accuracy: 0.7011 - val_loss: 0.5709 - val_accuracy: 0.7070
# Epoch 15/100
# 43/43 [==============================] - 27s 632ms/step - loss: 0.5521 - accuracy: 0.7168 - val_loss: 0.5512 - val_accuracy: 0.7169
# Epoch 16/100
# 43/43 [==============================] - 27s 631ms/step - loss: 0.5285 - accuracy: 0.7295 - val_loss: 0.5276 - val_accuracy: 0.7365
# Epoch 17/100
# 43/43 [==============================] - 26s 606ms/step - loss: 0.5116 - accuracy: 0.7506 - val_loss: 0.5131 - val_accuracy: 0.7496
# Epoch 18/100
# 43/43 [==============================] - 26s 604ms/step - loss: 0.4853 - accuracy: 0.7632 - val_loss: 0.5087 - val_accuracy: 0.7545
# Epoch 19/100
# 43/43 [==============================] - 27s 624ms/step - loss: 0.4507 - accuracy: 0.7845 - val_loss: 0.4717 - val_accuracy: 0.7774
# Epoch 20/100
# 43/43 [==============================] - 27s 628ms/step - loss: 0.4561 - accuracy: 0.7885 - val_loss: 0.4454 - val_accuracy: 0.7938
# Epoch 21/100
# 43/43 [==============================] - 27s 619ms/step - loss: 0.4194 - accuracy: 0.8127 - val_loss: 0.4021 - val_accuracy: 0.8183
# Epoch 22/100
# 43/43 [==============================] - 27s 623ms/step - loss: 0.3946 - accuracy: 0.8251 - val_loss: 0.4048 - val_accuracy: 0.8331
# Epoch 23/100
# 43/43 [==============================] - 26s 609ms/step - loss: 0.3775 - accuracy: 0.8309 - val_loss: 0.3910 - val_accuracy: 0.8347
# Epoch 24/100
# 43/43 [==============================] - 27s 632ms/step - loss: 0.3521 - accuracy: 0.8382 - val_loss: 0.3521 - val_accuracy: 0.8674
# Epoch 25/100
# 43/43 [==============================] - 29s 684ms/step - loss: 0.3249 - accuracy: 0.8575 - val_loss: 0.3228 - val_accuracy: 0.8609
# Epoch 26/100
# 43/43 [==============================] - 28s 658ms/step - loss: 0.3163 - accuracy: 0.8660 - val_loss: 0.3207 - val_accuracy: 0.8756
# Epoch 27/100
# 43/43 [==============================] - 28s 652ms/step - loss: 0.2852 - accuracy: 0.8813 - val_loss: 0.2859 - val_accuracy: 0.8969
# Epoch 28/100
# 43/43 [==============================] - 28s 645ms/step - loss: 0.2805 - accuracy: 0.8813 - val_loss: 0.3041 - val_accuracy: 0.8838
# Epoch 29/100
# 43/43 [==============================] - 27s 639ms/step - loss: 0.2398 - accuracy: 0.9028 - val_loss: 0.2639 - val_accuracy: 0.8969
# Epoch 30/100
# 43/43 [==============================] - 28s 653ms/step - loss: 0.2373 - accuracy: 0.9046 - val_loss: 0.3028 - val_accuracy: 0.8674
# Epoch 31/100
# 43/43 [==============================] - 29s 670ms/step - loss: 0.2362 - accuracy: 0.9035 - val_loss: 0.2414 - val_accuracy: 0.9034
# Epoch 32/100
# 43/43 [==============================] - 28s 663ms/step - loss: 0.2156 - accuracy: 0.9146 - val_loss: 0.2334 - val_accuracy: 0.9264
# Epoch 33/100
# 43/43 [==============================] - 28s 647ms/step - loss: 0.1961 - accuracy: 0.9236 - val_loss: 0.2452 - val_accuracy: 0.9198
# Epoch 34/100
# 43/43 [==============================] - 28s 646ms/step - loss: 0.2038 - accuracy: 0.9172 - val_loss: 0.2052 - val_accuracy: 0.9362
# Epoch 35/100
# 43/43 [==============================] - 28s 654ms/step - loss: 0.1821 - accuracy: 0.9294 - val_loss: 0.1884 - val_accuracy: 0.9264
# Epoch 36/100
# 43/43 [==============================] - 27s 628ms/step - loss: 0.1842 - accuracy: 0.9270 - val_loss: 0.1613 - val_accuracy: 0.9427
# Epoch 37/100
# 43/43 [==============================] - 28s 658ms/step - loss: 0.1700 - accuracy: 0.9339 - val_loss: 0.1693 - val_accuracy: 0.9476
# Epoch 38/100
# 43/43 [==============================] - 26s 615ms/step - loss: 0.1681 - accuracy: 0.9339 - val_loss: 0.1600 - val_accuracy: 0.9378
# Epoch 39/100
# 43/43 [==============================] - 26s 614ms/step - loss: 0.1615 - accuracy: 0.9410 - val_loss: 0.1711 - val_accuracy: 0.9493
# Epoch 40/100
# 43/43 [==============================] - 27s 629ms/step - loss: 0.1585 - accuracy: 0.9374 - val_loss: 0.1680 - val_accuracy: 0.9444
# Epoch 41/100
# 43/43 [==============================] - 28s 644ms/step - loss: 0.1637 - accuracy: 0.9347 - val_loss: 0.1439 - val_accuracy: 0.9542
# Epoch 42/100
# 43/43 [==============================] - 28s 646ms/step - loss: 0.1360 - accuracy: 0.9483 - val_loss: 0.1550 - val_accuracy: 0.9558
# Epoch 43/100
# 43/43 [==============================] - 28s 655ms/step - loss: 0.1287 - accuracy: 0.9530 - val_loss: 0.1425 - val_accuracy: 0.9542
# Epoch 44/100
# 43/43 [==============================] - 29s 669ms/step - loss: 0.1266 - accuracy: 0.9503 - val_loss: 0.1547 - val_accuracy: 0.9542
# Epoch 45/100
# 43/43 [==============================] - 28s 663ms/step - loss: 0.1291 - accuracy: 0.9510 - val_loss: 0.1618 - val_accuracy: 0.9509
# Epoch 46/100
# 43/43 [==============================] - 29s 668ms/step - loss: 0.1352 - accuracy: 0.9523 - val_loss: 0.1378 - val_accuracy: 0.9542
# Epoch 47/100
# 43/43 [==============================] - 27s 625ms/step - loss: 0.1180 - accuracy: 0.9561 - val_loss: 0.1297 - val_accuracy: 0.9574
# Epoch 48/100
# 43/43 [==============================] - 28s 650ms/step - loss: 0.1044 - accuracy: 0.9620 - val_loss: 0.1432 - val_accuracy: 0.9525
# Epoch 49/100
# 43/43 [==============================] - 29s 686ms/step - loss: 0.1003 - accuracy: 0.9649 - val_loss: 0.1482 - val_accuracy: 0.9542
# Epoch 50/100
# 43/43 [==============================] - 28s 651ms/step - loss: 0.1194 - accuracy: 0.9567 - val_loss: 0.1423 - val_accuracy: 0.9525
# Epoch 51/100
# 43/43 [==============================] - 29s 671ms/step - loss: 0.0939 - accuracy: 0.9636 - val_loss: 0.1129 - val_accuracy: 0.9640
# Epoch 52/100
# 43/43 [==============================] - 29s 669ms/step - loss: 0.0908 - accuracy: 0.9674 - val_loss: 0.1274 - val_accuracy: 0.9591
# Epoch 53/100
# 43/43 [==============================] - 29s 669ms/step - loss: 0.0753 - accuracy: 0.9734 - val_loss: 0.1312 - val_accuracy: 0.9624
# Epoch 54/100
# 43/43 [==============================] - 28s 661ms/step - loss: 0.0932 - accuracy: 0.9661 - val_loss: 0.1032 - val_accuracy: 0.9640
# Epoch 55/100
# 43/43 [==============================] - 28s 641ms/step - loss: 0.0839 - accuracy: 0.9722 - val_loss: 0.0990 - val_accuracy: 0.9689
# Epoch 56/100
# 43/43 [==============================] - 28s 641ms/step - loss: 0.0796 - accuracy: 0.9696 - val_loss: 0.1045 - val_accuracy: 0.9656
# Epoch 57/100
# 43/43 [==============================] - 27s 625ms/step - loss: 0.0809 - accuracy: 0.9711 - val_loss: 0.1313 - val_accuracy: 0.9509
# Epoch 58/100
# 43/43 [==============================] - 28s 657ms/step - loss: 0.0747 - accuracy: 0.9754 - val_loss: 0.1131 - val_accuracy: 0.9558
# Epoch 59/100
# 43/43 [==============================] - 27s 625ms/step - loss: 0.0787 - accuracy: 0.9740 - val_loss: 0.1221 - val_accuracy: 0.9640
# Epoch 60/100
# 43/43 [==============================] - 27s 623ms/step - loss: 0.0794 - accuracy: 0.9731 - val_loss: 0.1206 - val_accuracy: 0.9542
# Epoch 61/100
# 43/43 [==============================] - 27s 622ms/step - loss: 0.0698 - accuracy: 0.9749 - val_loss: 0.0963 - val_accuracy: 0.9640
# Epoch 62/100
# 43/43 [==============================] - 27s 624ms/step - loss: 0.0723 - accuracy: 0.9740 - val_loss: 0.1010 - val_accuracy: 0.9607
# Epoch 63/100
# 43/43 [==============================] - 28s 662ms/step - loss: 0.0702 - accuracy: 0.9756 - val_loss: 0.0888 - val_accuracy: 0.9640
# Epoch 64/100
# 43/43 [==============================] - 28s 663ms/step - loss: 0.0639 - accuracy: 0.9796 - val_loss: 0.1193 - val_accuracy: 0.9624
# Epoch 65/100
# 43/43 [==============================] - 29s 675ms/step - loss: 0.0715 - accuracy: 0.9732 - val_loss: 0.1128 - val_accuracy: 0.9656
# Epoch 66/100
# 43/43 [==============================] - 27s 631ms/step - loss: 0.0675 - accuracy: 0.9760 - val_loss: 0.0906 - val_accuracy: 0.9738
# Epoch 67/100
# 43/43 [==============================] - 27s 625ms/step - loss: 0.0632 - accuracy: 0.9765 - val_loss: 0.1128 - val_accuracy: 0.9574
# Epoch 68/100
# 43/43 [==============================] - 28s 646ms/step - loss: 0.0518 - accuracy: 0.9820 - val_loss: 0.0801 - val_accuracy: 0.9656
# Epoch 69/100
# 43/43 [==============================] - 27s 639ms/step - loss: 0.0475 - accuracy: 0.9798 - val_loss: 0.0656 - val_accuracy: 0.9689
# Epoch 70/100
# 43/43 [==============================] - 27s 636ms/step - loss: 0.0543 - accuracy: 0.9822 - val_loss: 0.0637 - val_accuracy: 0.9755
# Epoch 71/100
# 43/43 [==============================] - 28s 650ms/step - loss: 0.0669 - accuracy: 0.9760 - val_loss: 0.0724 - val_accuracy: 0.9738
# Epoch 72/100
# 43/43 [==============================] - 28s 644ms/step - loss: 0.0673 - accuracy: 0.9742 - val_loss: 0.0915 - val_accuracy: 0.9656
# Epoch 73/100
# 43/43 [==============================] - 29s 674ms/step - loss: 0.0661 - accuracy: 0.9763 - val_loss: 0.0945 - val_accuracy: 0.9640
# Epoch 74/100
# 43/43 [==============================] - 32s 753ms/step - loss: 0.0576 - accuracy: 0.9798 - val_loss: 0.1167 - val_accuracy: 0.9689
# Epoch 75/100
# 43/43 [==============================] - 32s 735ms/step - loss: 0.0507 - accuracy: 0.9809 - val_loss: 0.1155 - val_accuracy: 0.9624
# Epoch 76/100
# 43/43 [==============================] - 32s 741ms/step - loss: 0.0545 - accuracy: 0.9796 - val_loss: 0.0826 - val_accuracy: 0.9673
# Epoch 77/100
# 43/43 [==============================] - 30s 686ms/step - loss: 0.0556 - accuracy: 0.9787 - val_loss: 0.0843 - val_accuracy: 0.9722
# Epoch 78/100
# 43/43 [==============================] - 32s 734ms/step - loss: 0.0441 - accuracy: 0.9849 - val_loss: 0.1003 - val_accuracy: 0.9689
# Epoch 79/100
# 43/43 [==============================] - 29s 682ms/step - loss: 0.0499 - accuracy: 0.9827 - val_loss: 0.0903 - val_accuracy: 0.9705
# Epoch 80/100
# 43/43 [==============================] - 29s 677ms/step - loss: 0.0506 - accuracy: 0.9825 - val_loss: 0.0844 - val_accuracy: 0.9705
# Epoch 81/100
# 43/43 [==============================] - 30s 691ms/step - loss: 0.0443 - accuracy: 0.9847 - val_loss: 0.0714 - val_accuracy: 0.9804
# Epoch 82/100
# 43/43 [==============================] - 29s 684ms/step - loss: 0.0510 - accuracy: 0.9825 - val_loss: 0.1099 - val_accuracy: 0.9656
# Epoch 83/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.0509 - accuracy: 0.9840 - val_loss: 0.1116 - val_accuracy: 0.9689
# Epoch 84/100
# 43/43 [==============================] - 30s 688ms/step - loss: 0.0552 - accuracy: 0.9794 - val_loss: 0.1081 - val_accuracy: 0.9640
# Epoch 85/100
# 43/43 [==============================] - 30s 704ms/step - loss: 0.0468 - accuracy: 0.9842 - val_loss: 0.0601 - val_accuracy: 0.9804
# Epoch 86/100
# 43/43 [==============================] - 30s 699ms/step - loss: 0.0413 - accuracy: 0.9840 - val_loss: 0.0797 - val_accuracy: 0.9755
# Epoch 87/100
# 43/43 [==============================] - 30s 688ms/step - loss: 0.0459 - accuracy: 0.9842 - val_loss: 0.0823 - val_accuracy: 0.9820
# Epoch 88/100
# 43/43 [==============================] - 29s 676ms/step - loss: 0.0381 - accuracy: 0.9871 - val_loss: 0.1070 - val_accuracy: 0.9656
# Epoch 89/100
# 43/43 [==============================] - 27s 633ms/step - loss: 0.0411 - accuracy: 0.9862 - val_loss: 0.0804 - val_accuracy: 0.9722
# Epoch 90/100
# 43/43 [==============================] - 27s 626ms/step - loss: 0.0481 - accuracy: 0.9834 - val_loss: 0.1020 - val_accuracy: 0.9689
# Epoch 91/100
# 43/43 [==============================] - 27s 629ms/step - loss: 0.0409 - accuracy: 0.9858 - val_loss: 0.0902 - val_accuracy: 0.9656
# Epoch 92/100
# 43/43 [==============================] - 27s 626ms/step - loss: 0.0460 - accuracy: 0.9822 - val_loss: 0.1142 - val_accuracy: 0.9705
# Epoch 93/100
# 43/43 [==============================] - 27s 632ms/step - loss: 0.0377 - accuracy: 0.9862 - val_loss: 0.1015 - val_accuracy: 0.9705
# Epoch 94/100
# 43/43 [==============================] - 27s 633ms/step - loss: 0.0403 - accuracy: 0.9860 - val_loss: 0.1013 - val_accuracy: 0.9705
# Epoch 95/100
# 43/43 [==============================] - 27s 630ms/step - loss: 0.0627 - accuracy: 0.9767 - val_loss: 0.0719 - val_accuracy: 0.9771
# Epoch 96/100
# 43/43 [==============================] - 28s 661ms/step - loss: 0.0420 - accuracy: 0.9847 - val_loss: 0.0982 - val_accuracy: 0.9640
# Epoch 97/100
# 43/43 [==============================] - 30s 686ms/step - loss: 0.0533 - accuracy: 0.9827 - val_loss: 0.1042 - val_accuracy: 0.9689
# Epoch 98/100
# 43/43 [==============================] - 28s 661ms/step - loss: 0.0392 - accuracy: 0.9863 - val_loss: 0.1005 - val_accuracy: 0.9705
# Epoch 99/100
# 43/43 [==============================] - 29s 667ms/step - loss: 0.0437 - accuracy: 0.9858 - val_loss: 0.0800 - val_accuracy: 0.9755
# Epoch 100/100
# 43/43 [==============================] - 28s 645ms/step - loss: 0.0417 - accuracy: 0.9869 - val_loss: 0.0916 - val_accuracy: 0.9738
# Time:  2792.36 seconds

# %%
# Final evaluation of the model
adv_scores = adv_model.evaluate(X_test, y_test, batch_size=batchsize)
# Out:
# 12/12 [==============================] - 2s 150ms/step - loss: 0.1428 - accuracy: 0.9555

# %%
# Saving the model
adv_model.save('adv_model_breastCancer_INbreast.h5')

# %%
print("The Accuracy For Advanced CNN Model for INbreast Dataset:", round(adv_scores[1]*100,3), "%")
# Out:
# The Accuracy For Advanced CNN Model for INbreast Dataset: 95.547 %

# %%
# Testing an image from the Test set
print("Testing an image from Test Dataset -")
Test_image = X_test[0:1]
print("Shape of test image - ", Test_image.shape)
predict_x=adv_model.predict(Test_image) 
classes_x=np.argmax(predict_x, axis=1)
print("Predicted class - ", classes_x)
print("Predicted Accuracy - ", adv_model.predict(Test_image))
# Out:
# Testing an image from Test Dataset -
# Shape of test image -  (1, 92, 140, 3)
# 1/1 [==============================] - 0s 111ms/step
# Predicted class -  [0]
# 1/1 [==============================] - 0s 20ms/step
# Predicted Accuracy -  [[9.999999e-01 6.485033e-08]]

# %%
# visualizing losses and accuracy
train_accuracy = adv_hist.history['accuracy']
val_accuracy = adv_hist.history['val_accuracy']
train_loss = adv_hist.history['loss']
val_loss = adv_hist.history['val_loss']

# %%
# Losses
xc = range(num_of_epochs)
plt.figure(figsize=(5,7))
plt.plot(xc, val_loss)
plt.plot(xc, train_loss)
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss','Validation Loss'], loc=3)
plt.title('Training Loss V/s Validation Loss')
plt.grid(True)

# %%
# Accuracy
xc = range(num_of_epochs)
plt.figure(figsize=(5,7))
plt.plot(xc, val_accuracy)
plt.plot(xc, train_accuracy)
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Acc','Validation Acc'], loc=4)
plt.title('Training Accuracy V/s Validation Accuracy')
plt.grid(True)

# %%
# Testing a random image in INbreast Data
print("Testing a Random Malignant Image in INbreast Dataset -")
loc = 'E:/NN project/Dataset of Mammography with Benign Malignant Breast Masses/INbreast Dataset/test/Malignant Masses/20586934 (18).png'
loc2 = 'E:/NN project/Dataset of Mammography with Benign Malignant Breast Masses/INbreast Dataset/test/Benign Masses/20587902 (64).png'
test_image = cv2.imread(loc)
test_image = cv2.resize(test_image, (140,92))
test_image = np.array(test_image)
test_image = test_image.astype('float32')
test_image = test_image/255
test_image = np.expand_dims(test_image, axis=0)

print("Shape of test image -", test_image.shape)
print("Predicted accuracies -", adv_model.predict(test_image))
predict_x_value = adv_model.predict(test_image) 
classes_x=np.argmax(predict_x_value, axis=1)
print("Predicted class -", classes_x)
# Out:
# Testing a Random Malignant Image in INbreast Dataset -
# Shape of test image - (1, 92, 140, 3)
# 1/1 [==============================] - 0s 19ms/step
# Predicted accuracies - [[9.9979395e-01 2.0603530e-04]]
# 1/1 [==============================] - 0s 18ms/step
# Predicted class - [0]

# %%
# Classification Report 
y_pred_value = adv_model.predict(X_test, verbose=1)
yhat_classes = np.argmax(y_pred_value, axis=1)

y_test_value = np.argmax(y_test, axis=1)
print(classification_report(y_test_value, yhat_classes))
# Out:
# 48/48 [==============================] - 2s 48ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1044
#            1       0.98      0.88      0.93       483
#
#     accuracy                           0.96      1527
#    macro avg       0.96      0.93      0.95      1527
# weighted avg       0.96      0.96      0.95      1527
