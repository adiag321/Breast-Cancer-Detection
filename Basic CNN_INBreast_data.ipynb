# %% [markdown]
# # 1. Breast Cancer Detection Using INbreast Dataset (Basic CNN Model)

# %% [markdown]
# #### 1.1 Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import pydot
import matplotlib.pyplot as plt
import cv2
import os
from numpy.random import seed
seed(101)

import tensorflow
from keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model

import h5py
from keras.utils import np_utils
from keras import backend as K
from keras.models import load_model 
from keras.utils.vis_utils import plot_model
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import timeit
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### 1.2 Loading the dataset

# %%
## loading the INbreast data
folder_path_INbreast = 'E:/NN project/Dataset of Mammography with Benign Malignant Breast Masses/INbreast Dataset/'
num_of_epochs = 100
batchsize = 128
image_class_label = 0
INbreast_data_labels = []
INbreast_data_images = []

# %%
def loading_images_from_folder(folder, image_class_label):
	for file_name in os.listdir(folder):
		og_img = cv2.imread(os.path.join(folder, file_name))
		if og_img is not None:
			og_img = cv2.resize(og_img, (140,92))  ## resizing the image
			og_img = og_img.reshape(92,140,3)
			INbreast_data_images.append(og_img)				 ## Appending all the resized Images
			INbreast_data_labels.append(image_class_label)		 ## Adding the respective labels
		
	image_class_label += 1
	return image_class_label

# %%
image_class_label = loading_images_from_folder(folder_path_INbreast+'Malignant Masses', image_class_label)
image_class_label = loading_images_from_folder(folder_path_INbreast+'Benign Masses', image_class_label)

# %%
# converting the images to an array
INbreast_Data = np.asarray(INbreast_data_images)
INbreast_Labels = np.asarray(INbreast_data_labels)
print("Shape of InBreast Data - ", INbreast_Data.shape)
# Out:
# Shape of InBreast Data -  (7632, 92, 140, 3)

# %% [markdown]
# #### 1.3 Splitting INbreast dataset

# %%
# Splitting the "INbreast" Data as Train, Validation and Test
X_train, X_test, y_train, y_test = train_test_split(INbreast_Data, INbreast_Labels, test_size=0.2, random_state=21)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1)

# %%
## Size of dataset before Normalization
print("Before Normalization -")
print("Shape of X Train = ", X_train.shape, "Shape of X test = ", X_test.shape)
print("Shape of Y Train = ", y_train.shape, "Shape of Y Test = ", y_test.shape)
print("Shape of X Validation = ", X_valid.shape, "Shape of Y Validation = ", y_valid.shape)
# Out:
# Before Normalization -
# Shape of X Train =  (5494, 92, 140, 3) Shape of X test =  (1527, 92, 140, 3)
# Shape of Y Train =  (5494,) Shape of Y Test =  (1527,)
# Shape of X Validation =  (611, 92, 140, 3) Shape of Y Validation =  (611,)

# %%
# Normalizing the data
X_train = X_train / 255  ## original scale : 255
X_valid = X_valid / 255         ## new image scale : 0-1
X_test = X_test / 255
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_valid = np_utils.to_categorical(y_valid)
y_test = np_utils.to_categorical(y_test)
number_of_classes = y_test.shape[1]

# %%
# Printing the results After Normalization
print("After Normalization -")
print("Shape of X Train = ", X_train.shape, "Shape of X test = ", X_test.shape)
print("Shape of Y Train = ", y_train.shape, "Shape of Y Test = ", y_test.shape)
print("Shape of X Validation = ", X_valid.shape, "Shape of Y Validation = ", y_valid.shape)
# Out:
# After Normalization -
# Shape of X Train =  (5494, 92, 140, 3) Shape of X test =  (1527, 92, 140, 3)
# Shape of Y Train =  (5494, 2) Shape of Y Test =  (1527, 2)
# Shape of X Validation =  (611, 92, 140, 3) Shape of Y Validation =  (611, 2)

# %%
# Showing the Images
plt.figure(figsize=(11,3))
for i in range(10):
  plt.subplot(2,5,1+i)
  plt.imshow(X_train[i], cmap='gray')

# %% [markdown]
# #### 1.4.1 Basic Building Model for INbreast Data

# %%
# BASIC CNN model for INbreast Dataset
def basic_breastCancer_model():
	basic_model = Sequential()
	basic_model.add(Conv2D(32, (3, 3), padding="same", input_shape=(92,140,3), activation='relu'))
	basic_model.add(MaxPooling2D(pool_size=(2, 2)))
	basic_model.add(Conv2D(32, (3, 3), activation='relu', padding = 'same'))
	basic_model.add(MaxPooling2D(pool_size=(2, 2)))
	basic_model.add(Flatten())
	basic_model.add(Dropout(0.5))
	basic_model.add(Dense(50, activation='relu'))
	basic_model.add(Dropout(0.2))
	basic_model.add(Dense(number_of_classes, activation='softmax'))

	basic_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
	return basic_model

# %%
# Building the model
basic_model = basic_breastCancer_model()
basic_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 92, 140, 32)       896
#
#  max_pooling2d (MaxPooling2D  (None, 46, 70, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 46, 70, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 35, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 25760)             0
#
#  dropout (Dropout)           (None, 25760)             0
#
#  dense (Dense)               (None, 50)                1288050
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 1,298,296
# Trainable params: 1,298,296
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the CNN model
start = timeit.default_timer()
hist = basic_model.fit(X_train, y_train, validation_data=(X_valid, y_valid),
                         batch_size=batchsize, epochs=num_of_epochs)
stop = timeit.default_timer()
print("Time: ", round((stop - start),2), "seconds")
# Out:
# Epoch 1/100
# 43/43 [==============================] - 25s 561ms/step - loss: 0.6555 - accuracy: 0.6460 - val_loss: 0.6307 - val_accuracy: 0.6694
# Epoch 2/100
# 43/43 [==============================] - 23s 542ms/step - loss: 0.6318 - accuracy: 0.6660 - val_loss: 0.6267 - val_accuracy: 0.6694
# Epoch 3/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.6210 - accuracy: 0.6660 - val_loss: 0.6226 - val_accuracy: 0.6694
# Epoch 4/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.5943 - accuracy: 0.6655 - val_loss: 0.5973 - val_accuracy: 0.6694
# Epoch 5/100
# 43/43 [==============================] - 23s 526ms/step - loss: 0.5621 - accuracy: 0.6773 - val_loss: 0.5638 - val_accuracy: 0.6890
# Epoch 6/100
# 43/43 [==============================] - 23s 532ms/step - loss: 0.5293 - accuracy: 0.7252 - val_loss: 0.5455 - val_accuracy: 0.6989
# Epoch 7/100
# 43/43 [==============================] - 23s 531ms/step - loss: 0.4874 - accuracy: 0.7485 - val_loss: 0.5005 - val_accuracy: 0.7201
# Epoch 8/100
# 43/43 [==============================] - 24s 552ms/step - loss: 0.4370 - accuracy: 0.7907 - val_loss: 0.4625 - val_accuracy: 0.7692
# Epoch 9/100
# 43/43 [==============================] - 25s 571ms/step - loss: 0.3907 - accuracy: 0.8218 - val_loss: 0.4215 - val_accuracy: 0.8101
# Epoch 10/100
# 43/43 [==============================] - 25s 575ms/step - loss: 0.3431 - accuracy: 0.8475 - val_loss: 0.3612 - val_accuracy: 0.8527
# Epoch 11/100
# 43/43 [==============================] - 26s 598ms/step - loss: 0.2949 - accuracy: 0.8735 - val_loss: 0.3397 - val_accuracy: 0.8478
# Epoch 12/100
# 43/43 [==============================] - 23s 545ms/step - loss: 0.2642 - accuracy: 0.8828 - val_loss: 0.3057 - val_accuracy: 0.8658
# Epoch 13/100
# 43/43 [==============================] - 23s 524ms/step - loss: 0.2281 - accuracy: 0.9041 - val_loss: 0.2952 - val_accuracy: 0.8740
# Epoch 14/100
# 43/43 [==============================] - 22s 521ms/step - loss: 0.2036 - accuracy: 0.9165 - val_loss: 0.2497 - val_accuracy: 0.9034
# Epoch 15/100
# 43/43 [==============================] - 23s 534ms/step - loss: 0.1797 - accuracy: 0.9265 - val_loss: 0.2390 - val_accuracy: 0.9067
# Epoch 16/100
# 43/43 [==============================] - 24s 561ms/step - loss: 0.1628 - accuracy: 0.9368 - val_loss: 0.2017 - val_accuracy: 0.9313
# Epoch 17/100
# 43/43 [==============================] - 23s 540ms/step - loss: 0.1467 - accuracy: 0.9441 - val_loss: 0.2342 - val_accuracy: 0.9067
# Epoch 18/100
# 43/43 [==============================] - 23s 533ms/step - loss: 0.1448 - accuracy: 0.9423 - val_loss: 0.1959 - val_accuracy: 0.9345
# Epoch 19/100
# 43/43 [==============================] - 22s 523ms/step - loss: 0.1253 - accuracy: 0.9543 - val_loss: 0.1766 - val_accuracy: 0.9345
# Epoch 20/100
# 43/43 [==============================] - 23s 529ms/step - loss: 0.1153 - accuracy: 0.9580 - val_loss: 0.1611 - val_accuracy: 0.9525
# Epoch 21/100
# 43/43 [==============================] - 23s 535ms/step - loss: 0.1054 - accuracy: 0.9625 - val_loss: 0.1833 - val_accuracy: 0.9378
# Epoch 22/100
# 43/43 [==============================] - 24s 552ms/step - loss: 0.0921 - accuracy: 0.9672 - val_loss: 0.1724 - val_accuracy: 0.9313
# Epoch 23/100
# 43/43 [==============================] - 23s 531ms/step - loss: 0.0937 - accuracy: 0.9671 - val_loss: 0.1537 - val_accuracy: 0.9493
# Epoch 24/100
# 43/43 [==============================] - 23s 524ms/step - loss: 0.0839 - accuracy: 0.9700 - val_loss: 0.1547 - val_accuracy: 0.9574
# Epoch 25/100
# 43/43 [==============================] - 23s 536ms/step - loss: 0.0775 - accuracy: 0.9731 - val_loss: 0.1528 - val_accuracy: 0.9542
# Epoch 26/100
# 43/43 [==============================] - 24s 549ms/step - loss: 0.0768 - accuracy: 0.9723 - val_loss: 0.1515 - val_accuracy: 0.9525
# Epoch 27/100
# 43/43 [==============================] - 24s 549ms/step - loss: 0.0669 - accuracy: 0.9756 - val_loss: 0.1622 - val_accuracy: 0.9444
# Epoch 28/100
# 43/43 [==============================] - 22s 522ms/step - loss: 0.0701 - accuracy: 0.9758 - val_loss: 0.1739 - val_accuracy: 0.9542
# Epoch 29/100
# 43/43 [==============================] - 23s 540ms/step - loss: 0.0610 - accuracy: 0.9780 - val_loss: 0.1636 - val_accuracy: 0.9476
# Epoch 30/100
# 43/43 [==============================] - 24s 547ms/step - loss: 0.0639 - accuracy: 0.9776 - val_loss: 0.1512 - val_accuracy: 0.9558
# Epoch 31/100
# 43/43 [==============================] - 24s 552ms/step - loss: 0.0556 - accuracy: 0.9787 - val_loss: 0.1671 - val_accuracy: 0.9558
# Epoch 32/100
# 43/43 [==============================] - 24s 566ms/step - loss: 0.0561 - accuracy: 0.9816 - val_loss: 0.1520 - val_accuracy: 0.9624
# Epoch 33/100
# 43/43 [==============================] - 24s 567ms/step - loss: 0.0582 - accuracy: 0.9794 - val_loss: 0.1465 - val_accuracy: 0.9574
# Epoch 34/100
# 43/43 [==============================] - 23s 525ms/step - loss: 0.0509 - accuracy: 0.9834 - val_loss: 0.1276 - val_accuracy: 0.9591
# Epoch 35/100
# 43/43 [==============================] - 23s 539ms/step - loss: 0.0496 - accuracy: 0.9829 - val_loss: 0.1614 - val_accuracy: 0.9558
# Epoch 36/100
# 43/43 [==============================] - 23s 539ms/step - loss: 0.0565 - accuracy: 0.9785 - val_loss: 0.1228 - val_accuracy: 0.9673
# Epoch 37/100
# 43/43 [==============================] - 23s 535ms/step - loss: 0.0517 - accuracy: 0.9842 - val_loss: 0.1368 - val_accuracy: 0.9624
# Epoch 38/100
# 43/43 [==============================] - 22s 504ms/step - loss: 0.0455 - accuracy: 0.9834 - val_loss: 0.1253 - val_accuracy: 0.9607
# Epoch 39/100
# 43/43 [==============================] - 21s 484ms/step - loss: 0.0437 - accuracy: 0.9849 - val_loss: 0.1559 - val_accuracy: 0.9656
# Epoch 40/100
# 43/43 [==============================] - 21s 486ms/step - loss: 0.0391 - accuracy: 0.9873 - val_loss: 0.1502 - val_accuracy: 0.9607
# Epoch 41/100
# 43/43 [==============================] - 23s 542ms/step - loss: 0.0455 - accuracy: 0.9853 - val_loss: 0.1472 - val_accuracy: 0.9640
# Epoch 42/100
# 43/43 [==============================] - 22s 500ms/step - loss: 0.0343 - accuracy: 0.9896 - val_loss: 0.1628 - val_accuracy: 0.9558
# Epoch 43/100
# 43/43 [==============================] - 24s 571ms/step - loss: 0.0443 - accuracy: 0.9825 - val_loss: 0.1408 - val_accuracy: 0.9640
# Epoch 44/100
# 43/43 [==============================] - 22s 501ms/step - loss: 0.0387 - accuracy: 0.9882 - val_loss: 0.1199 - val_accuracy: 0.9607
# Epoch 45/100
# 43/43 [==============================] - 21s 499ms/step - loss: 0.0318 - accuracy: 0.9891 - val_loss: 0.1397 - val_accuracy: 0.9607
# Epoch 46/100
# 43/43 [==============================] - 21s 499ms/step - loss: 0.0362 - accuracy: 0.9873 - val_loss: 0.1863 - val_accuracy: 0.9493
# Epoch 47/100
# 43/43 [==============================] - 21s 499ms/step - loss: 0.0383 - accuracy: 0.9865 - val_loss: 0.1448 - val_accuracy: 0.9607
# Epoch 48/100
# 43/43 [==============================] - 22s 508ms/step - loss: 0.0334 - accuracy: 0.9887 - val_loss: 0.1347 - val_accuracy: 0.9509
# Epoch 49/100
# 43/43 [==============================] - 22s 501ms/step - loss: 0.0381 - accuracy: 0.9873 - val_loss: 0.1719 - val_accuracy: 0.9607
# Epoch 50/100
# 43/43 [==============================] - 21s 500ms/step - loss: 0.0334 - accuracy: 0.9894 - val_loss: 0.1695 - val_accuracy: 0.9574
# Epoch 51/100
# 43/43 [==============================] - 22s 501ms/step - loss: 0.0270 - accuracy: 0.9911 - val_loss: 0.1747 - val_accuracy: 0.9607
# Epoch 52/100
# 43/43 [==============================] - 22s 512ms/step - loss: 0.0316 - accuracy: 0.9891 - val_loss: 0.2045 - val_accuracy: 0.9574
# Epoch 53/100
# 43/43 [==============================] - 22s 509ms/step - loss: 0.0364 - accuracy: 0.9874 - val_loss: 0.1744 - val_accuracy: 0.9640
# Epoch 54/100
# 43/43 [==============================] - 22s 504ms/step - loss: 0.0284 - accuracy: 0.9914 - val_loss: 0.1530 - val_accuracy: 0.9673
# Epoch 55/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.0300 - accuracy: 0.9905 - val_loss: 0.1533 - val_accuracy: 0.9673
# Epoch 56/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.0334 - accuracy: 0.9882 - val_loss: 0.1466 - val_accuracy: 0.9656
# Epoch 57/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.0311 - accuracy: 0.9909 - val_loss: 0.1444 - val_accuracy: 0.9689
# Epoch 58/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.0221 - accuracy: 0.9940 - val_loss: 0.1518 - val_accuracy: 0.9591
# Epoch 59/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.0259 - accuracy: 0.9909 - val_loss: 0.1358 - val_accuracy: 0.9656
# Epoch 60/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.0281 - accuracy: 0.9894 - val_loss: 0.1524 - val_accuracy: 0.9689
# Epoch 61/100
# 43/43 [==============================] - 23s 526ms/step - loss: 0.0288 - accuracy: 0.9896 - val_loss: 0.1669 - val_accuracy: 0.9591
# Epoch 62/100
# 43/43 [==============================] - 23s 537ms/step - loss: 0.0243 - accuracy: 0.9929 - val_loss: 0.1623 - val_accuracy: 0.9591
# Epoch 63/100
# 43/43 [==============================] - 23s 526ms/step - loss: 0.0244 - accuracy: 0.9922 - val_loss: 0.1745 - val_accuracy: 0.9624
# Epoch 64/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.0268 - accuracy: 0.9905 - val_loss: 0.1929 - val_accuracy: 0.9558
# Epoch 65/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.0265 - accuracy: 0.9924 - val_loss: 0.1487 - val_accuracy: 0.9624
# Epoch 66/100
# 43/43 [==============================] - 22s 512ms/step - loss: 0.0264 - accuracy: 0.9907 - val_loss: 0.1503 - val_accuracy: 0.9542
# Epoch 67/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.0276 - accuracy: 0.9896 - val_loss: 0.1631 - val_accuracy: 0.9558
# Epoch 68/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.0220 - accuracy: 0.9924 - val_loss: 0.1524 - val_accuracy: 0.9673
# Epoch 69/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.0250 - accuracy: 0.9916 - val_loss: 0.1529 - val_accuracy: 0.9689
# Epoch 70/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.0207 - accuracy: 0.9933 - val_loss: 0.1692 - val_accuracy: 0.9673
# Epoch 71/100
# 43/43 [==============================] - 24s 564ms/step - loss: 0.0213 - accuracy: 0.9920 - val_loss: 0.1715 - val_accuracy: 0.9591
# Epoch 72/100
# 43/43 [==============================] - 23s 527ms/step - loss: 0.0197 - accuracy: 0.9927 - val_loss: 0.1486 - val_accuracy: 0.9673
# Epoch 73/100
# 43/43 [==============================] - 24s 554ms/step - loss: 0.0183 - accuracy: 0.9936 - val_loss: 0.1755 - val_accuracy: 0.9607
# Epoch 74/100
# 43/43 [==============================] - 22s 518ms/step - loss: 0.0250 - accuracy: 0.9902 - val_loss: 0.1186 - val_accuracy: 0.9738
# Epoch 75/100
# 43/43 [==============================] - 22s 523ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 0.1641 - val_accuracy: 0.9624
# Epoch 76/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.0182 - accuracy: 0.9938 - val_loss: 0.1776 - val_accuracy: 0.9656
# Epoch 77/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.0168 - accuracy: 0.9942 - val_loss: 0.1458 - val_accuracy: 0.9656
# Epoch 78/100
# 43/43 [==============================] - 24s 550ms/step - loss: 0.0193 - accuracy: 0.9949 - val_loss: 0.1949 - val_accuracy: 0.9591
# Epoch 79/100
# 43/43 [==============================] - 22s 516ms/step - loss: 0.0257 - accuracy: 0.9922 - val_loss: 0.1705 - val_accuracy: 0.9574
# Epoch 80/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.0222 - accuracy: 0.9938 - val_loss: 0.1617 - val_accuracy: 0.9640
# Epoch 81/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.0176 - accuracy: 0.9942 - val_loss: 0.1770 - val_accuracy: 0.9624
# Epoch 82/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.0168 - accuracy: 0.9951 - val_loss: 0.2067 - val_accuracy: 0.9558
# Epoch 83/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.0252 - accuracy: 0.9914 - val_loss: 0.1940 - val_accuracy: 0.9542
# Epoch 84/100
# 43/43 [==============================] - 22s 513ms/step - loss: 0.0223 - accuracy: 0.9931 - val_loss: 0.1935 - val_accuracy: 0.9574
# Epoch 85/100
# 43/43 [==============================] - 28s 662ms/step - loss: 0.0258 - accuracy: 0.9925 - val_loss: 0.1744 - val_accuracy: 0.9558
# Epoch 86/100
# 43/43 [==============================] - 25s 587ms/step - loss: 0.0210 - accuracy: 0.9934 - val_loss: 0.1698 - val_accuracy: 0.9624
# Epoch 87/100
# 43/43 [==============================] - 24s 556ms/step - loss: 0.0248 - accuracy: 0.9929 - val_loss: 0.1332 - val_accuracy: 0.9640
# Epoch 88/100
# 43/43 [==============================] - 23s 524ms/step - loss: 0.0210 - accuracy: 0.9934 - val_loss: 0.1646 - val_accuracy: 0.9591
# Epoch 89/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.0221 - accuracy: 0.9925 - val_loss: 0.1594 - val_accuracy: 0.9624
# Epoch 90/100
# 43/43 [==============================] - 23s 540ms/step - loss: 0.0168 - accuracy: 0.9947 - val_loss: 0.1805 - val_accuracy: 0.9624
# Epoch 91/100
# 43/43 [==============================] - 22s 508ms/step - loss: 0.0203 - accuracy: 0.9927 - val_loss: 0.2043 - val_accuracy: 0.9591
# Epoch 92/100
# 43/43 [==============================] - 22s 522ms/step - loss: 0.0176 - accuracy: 0.9929 - val_loss: 0.1849 - val_accuracy: 0.9640
# Epoch 93/100
# 43/43 [==============================] - 22s 510ms/step - loss: 0.0237 - accuracy: 0.9914 - val_loss: 0.1750 - val_accuracy: 0.9640
# Epoch 94/100
# 43/43 [==============================] - 22s 512ms/step - loss: 0.0228 - accuracy: 0.9918 - val_loss: 0.1656 - val_accuracy: 0.9673
# Epoch 95/100
# 43/43 [==============================] - 22s 514ms/step - loss: 0.0216 - accuracy: 0.9920 - val_loss: 0.1773 - val_accuracy: 0.9656
# Epoch 96/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.0179 - accuracy: 0.9933 - val_loss: 0.1722 - val_accuracy: 0.9607
# Epoch 97/100
# 43/43 [==============================] - 22s 511ms/step - loss: 0.0238 - accuracy: 0.9924 - val_loss: 0.1652 - val_accuracy: 0.9574
# Epoch 98/100
# 43/43 [==============================] - 22s 518ms/step - loss: 0.0167 - accuracy: 0.9940 - val_loss: 0.1798 - val_accuracy: 0.9558
# Epoch 99/100
# 43/43 [==============================] - 22s 515ms/step - loss: 0.0147 - accuracy: 0.9953 - val_loss: 0.1715 - val_accuracy: 0.9722
# Epoch 100/100
# 43/43 [==============================] - 22s 505ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.1788 - val_accuracy: 0.9656
# Time:  2268.34 seconds

# %%
# Final evaluation of the model
scores = basic_model.evaluate(X_test, y_test, batch_size=batchsize)
# Out:
# 12/12 [==============================] - 1s 119ms/step - loss: 0.2250 - accuracy: 0.9659

# %%
# Saving the basic model
basic_model.save('basic_model_breastCancer_INbreast.h5')

# %%
print("The Accuracy For Basic CNN Model for INbreast Dataset:", round(scores[1]*100,3), "%")
# Out:
# The Accuracy For Basic CNN Model for INbreast Dataset: 96.595 %

# %%
# Testing an image from the Test set
print("Testing an image from Test Dataset -")
Test_image = X_test[0:1]
print("Shape of test image - ", Test_image.shape)
predict_x=basic_model.predict(Test_image) 
classes_x=np.argmax(predict_x, axis=1)
print("Predicted class - ", classes_x)
print("Predicted Accuracy - ", basic_model.predict(Test_image))
# Out:
# Testing an image from Test Dataset -
# Shape of test image -  (1, 92, 140, 3)
# 1/1 [==============================] - 0s 109ms/step
# Predicted class -  [0]
# 1/1 [==============================] - 0s 18ms/step
# Predicted Accuracy -  [[1.000000e+00 8.179854e-09]]

# %%
# visualizing losses and accuracy
train_accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']

# %%
# Losses
xc = range(num_of_epochs)
plt.figure(figsize=(5,7))
plt.plot(xc, val_loss)
plt.plot(xc, train_loss)
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss','Validation Loss'], loc=3)
plt.title('Training Loss V/s Validation Loss')
plt.grid(True)

# %%
# Accuracy
xc = range(num_of_epochs)
plt.figure(figsize=(5,7))
plt.plot(xc, val_accuracy)
plt.plot(xc, train_accuracy)
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Acc','Validation Acc'], loc=4)
plt.title('Training Accuracy V/s Validation Accuracy')
plt.grid(True)

# %%
# Testing a random image in INbreast Data
print("Testing a Random Malignant Image in INbreast Dataset -")
loc = 'E:/NN project/Dataset of Mammography with Benign Malignant Breast Masses/INbreast Dataset/test/Malignant Masses/20586934 (18).png'
loc2 = 'E:/NN project/Dataset of Mammography with Benign Malignant Breast Masses/INbreast Dataset/test/Benign Masses/20587902 (64).png'
test_image = cv2.imread(loc2)
test_image= cv2.resize(test_image, (140,92))
test_image = np.array(test_image)
test_image = test_image.astype('float32')
test_image = test_image/255
test_image = np.expand_dims(test_image, axis=0)

print("Shape of test image -", test_image.shape)
print("Predicted accuracies -", basic_model.predict(test_image))
predict_x_value = basic_model.predict(test_image) 
classes_x=np.argmax(predict_x_value, axis=1)
print("Predicted class -", classes_x)
# Out:
# Testing a Random Malignant Image in INbreast Dataset -
# Shape of test image - (1, 92, 140, 3)
# 1/1 [==============================] - 0s 21ms/step
# Predicted accuracies - [[1.7409018e-06 9.9999821e-01]]
# 1/1 [==============================] - 0s 19ms/step
# Predicted class - [1]

# %%
# Classification Report 
y_pred_value = basic_model.predict(X_test)
yhat_classes = np.argmax(y_pred_value,axis=1)

y_test_value = np.argmax(y_test, axis=1)
print(classification_report(y_test_value, yhat_classes))
# Out:
# 48/48 [==============================] - 2s 32ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1044
#            1       0.95      0.94      0.95       483
#
#     accuracy                           0.97      1527
#    macro avg       0.96      0.96      0.96      1527
# weighted avg       0.97      0.97      0.97      1527
